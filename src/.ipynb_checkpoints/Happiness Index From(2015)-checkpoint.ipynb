# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
#pd.set_option('html', True)
#pd.set_option('display.max_columns', 20)
#pd.set_option('display.max_rows', 25)

# %%
df = pd.read_csv("../data/Happiness Index/refugee_monthly.csv")
dfHP15 = pd.read_csv("../data/Happiness Index/2015.csv")
dfHP15
# Out:
#                       Country                           Region  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# 13                     Mexico      Latin America and Caribbean
# 14              United States                    North America
# 15                     Brazil      Latin America and Caribbean
# 16                 Luxembourg                   Western Europe
# 17                    Ireland                   Western Europe
# 18                    Belgium                   Western Europe
# 19       United Arab Emirates  Middle East and Northern Africa
# 20             United Kingdom                   Western Europe
# 21                       Oman  Middle East and Northern Africa
# 22                  Venezuela      Latin America and Caribbean
# 23                  Singapore                Southeastern Asia
# 24                     Panama      Latin America and Caribbean
# 25                    Germany                   Western Europe
# 26                      Chile      Latin America and Caribbean
# 27                      Qatar  Middle East and Northern Africa
# 28                     France                   Western Europe
# 29                  Argentina      Latin America and Caribbean
# ..                        ...                              ...
# 128                   Myanmar                Southeastern Asia
# 129                   Georgia       Central and Eastern Europe
# 130                    Malawi               Sub-Saharan Africa
# 131                 Sri Lanka                    Southern Asia
# 132                  Cameroon               Sub-Saharan Africa
# 133                  Bulgaria       Central and Eastern Europe
# 134                     Egypt  Middle East and Northern Africa
# 135                     Yemen  Middle East and Northern Africa
# 136                    Angola               Sub-Saharan Africa
# 137                      Mali               Sub-Saharan Africa
# 138       Congo (Brazzaville)               Sub-Saharan Africa
# 139                   Comoros               Sub-Saharan Africa
# 140                    Uganda               Sub-Saharan Africa
# 141                   Senegal               Sub-Saharan Africa
# 142                     Gabon               Sub-Saharan Africa
# 143                     Niger               Sub-Saharan Africa
# 144                  Cambodia                Southeastern Asia
# 145                  Tanzania               Sub-Saharan Africa
# 146                Madagascar               Sub-Saharan Africa
# 147  Central African Republic               Sub-Saharan Africa
# 148                      Chad               Sub-Saharan Africa
# 149                    Guinea               Sub-Saharan Africa
# 150               Ivory Coast               Sub-Saharan Africa
# 151              Burkina Faso               Sub-Saharan Africa
# 152               Afghanistan                    Southern Asia
# 153                    Rwanda               Sub-Saharan Africa
# 154                     Benin               Sub-Saharan Africa
# 155                     Syria  Middle East and Northern Africa
# 156                   Burundi               Sub-Saharan Africa
# 157                      Togo               Sub-Saharan Africa
#
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# 5                 6            7.406         0.03140
# 6                 7            7.378         0.02799
# 7                 8            7.364         0.03157
# 8                 9            7.286         0.03371
# 9                10            7.284         0.04083
# 10               11            7.278         0.03470
0.16681            1.56726
#
# [158 rows x 12 columns]

# %%
df = df.loc[df['Year'] == 2015]
df15Merged = df.merge(dfHP15, left_on = 'Country / territory of asylum/residence', right_on = 'Country', how ='inner')

# %%
df_grouped = df15Merged.groupby(['Country / territory of asylum/residence','Year']).agg({'Value':'sum','Happiness Score':'mean','Economy (GDP per Capita)':'mean','Family':'mean','Health (Life Expectancy)':'mean','Freedom':'mean','Trust (Government Corruption)':'mean'})
df_grouped.sort_values(['Value'],ascending = 0).head(5)
# Out:
#                                                Family  Freedom  \
# Country / territory of asylum/residence Year
# Germany                                 2015  1.29937  0.61477
# Hungary                                 2015  1.20215  0.32112
# Sweden                                  2015  1.28907  0.65980
# Turkey                                  2015  0.94632  0.22815
# Italy                                   2015  1.19777  0.26236
#
#                                               Happiness Score  \
# Country / territory of asylum/residence Year
# Germany                                 2015            6.750
# Hungary                                 2015            4.800
# Sweden                                  2015            7.364
# Turkey                                  2015            5.332
# Italy                                   2015            5.948
#
#                                               Trust (Government Corruption)  \
# Country / territory of asylum/residence Year
# Germany                                 2015                        0.21843
# Hungary                                 2015                        0.02758
# Sweden                                  2015                        0.43844
# Turkey                                  2015                        0.15746
# Italy                                   2015                        0.02901
#
#                                               Health (Life Expectancy)  \
# Country / territory of asylum/residence Year
# Germany                                 2015                   0.89186
# Hungary                                 2015                   0.75905
# Sweden                                  2015                   0.91087
# Turkey                                  2015                   0.73172
# Italy                                   2015                   0.95446
#
#                                                Value  Economy (GDP per Capita)
# Country / territory of asylum/residence Year
# Germany                                 2015  507323                   1.32792
# Hungary                                 2015  326008                   1.12094
# Sweden                                  2015  312918                   1.33171
# Turkey                                  2015  267170                   1.06098
# Italy                                   2015  166486                   1.25114

# %%
df_grouped = df_grouped.reset_index()
df_grouped = df_grouped.rename(columns={'Country / territory of asylum/residence': 'Country'})
df_grouped
# Out:
#                    Country  Year   Family  Freedom  Happiness Score  \
# 0                  Albania  2015  0.80434  0.35733            4.959
# 1                Australia  2015  1.30923  0.65124            7.284
# 2                  Austria  2015  1.29704  0.62433            7.200
# 3                  Belgium  2015  1.28566  0.58450            6.937
# 4   Bosnia and Herzegovina  2015  0.91916  0.09245            4.949
# 5                 Bulgaria  2015  1.10614  0.30587            4.218
# 6                   Canada  2015  1.32261  0.63297            7.427
# 7                  Croatia  2015  0.79624  0.25883            5.759
# 8                   Cyprus  2015  0.89318  0.40672            5.689
# 9                  Denmark  2015  1.36058  0.64938            7.527
# 10                 Estonia  2015  1.22791  0.44888            5.429
# 11                 Finland  2015  1.31826  0.64169            7.406
# 12                  France  2015  1.26038  0.55011            6.575
# 13                 Germany  2015  1.29937  0.61477            6.750
# 14                  Greece  2015  0.92933  0.07699            4.857
# 15                 Hungary  2015  1.20215  0.32112            4.800
# 16                 Iceland  2015  1.40223  0.62877            7.561
# 17                 Ireland  2015  1.36948  0.61777            6.940
# 18                   Italy  2015  1.19777  0.26236            5.948
# 19                   Japan  2015  1.25712  0.49615            5.987
# %%
del df_grouped['Value']
del df_grouped['Year']
del df_grouped['Happiness Score']

# %% [markdown]
# # Top 5 Countries People are seeking asylum to in 2015

# %%
dfGermany = df_grouped[(df_grouped['Country']=='Germany')]
df_grouped[(df_grouped['Country']=='Germany')]
ax = dfGermany.plot(kind = 'bar',title = "Germany Happiness",figsize=(16, 9))
ax.set_xlabel("Happiness Value Type", fontsize=20)
ax.set_ylabel("Rate of Happiness Value", fontsize=20)
ax.set_title("Germany Happiness", fontsize=30)
ax.set_ylim([0,1.4])
# Out:
# (0, 1.4)

# %% [markdown]
# ## Happiness Score is 6.75

# %%
dfGermany = df_grouped[(df_grouped['Country']=='Hungary')]
df_grouped[(df_grouped['Country']=='Hungary')]
ax = dfGermany.plot(kind = 'bar',title = "Hungary Happiness",figsize=(16, 9))
ax.set_xlabel("Happiness Value Type", fontsize=20)
ax.set_ylabel("Rate of Happiness Value", fontsize=20)
ax.set_title("Hungary Happiness", fontsize=30)
ax.set_ylim([0,1.4])
# Out:
# (0, 1.4)

# %% [markdown]
# ## Happiness Score is 4.80

# %%
dfGermany = df_grouped[(df_grouped['Country']=='Sweden')]
df_grouped[(df_grouped['Country']=='Sweden')]
ax = dfGermany.plot(kind = 'bar',title = "Sweden Happiness",figsize=(16, 9))
ax.set_xlabel("Happiness Value Type", fontsize=20)
ax.set_ylabel("Rate of Happiness Value", fontsize=20)
ax.set_title("Sweden Happiness", fontsize=30)
ax.set_ylim([0,1.4])
# Out:
# (0, 1.4)

# %% [markdown]
# ## Happiness Score is 7.364

# %%
dfGermany = df_grouped[(df_grouped['Country']=='Turkey')]
df_grouped[(df_grouped['Country']=='Turkey')]
ax = dfGermany.plot(kind = 'bar',title = "Turkey Happiness",figsize=(16, 9))
ax.set_xlabel("Happiness Value Type", fontsize=20)
ax.set_ylabel("Rate of Happiness Value", fontsize=20)
ax.set_title("Turkey Happiness", fontsize=30)
ax.set_ylim([0,1.4])
# Out:
# (0, 1.4)

# %% [markdown]
# ## Happiness Score is 5.332

# %%
dfGermany = df_grouped[(df_grouped['Country']=='Italy')]
df_grouped[(df_grouped['Country']=='Italy')]
ax = dfGermany.plot(kind = 'bar',title = "Italy Happiness",figsize=(16, 9))
ax.set_xlabel("Happiness Value Type", fontsize=20)
ax.set_ylabel("Rate of Happiness Value", fontsize=20)
ax.set_title("Italy Happiness", fontsize=30)
ax.set_ylim([0,1.4])
# Out:
# (0, 1.4)

# %% [markdown]
# ## Happiness Score is 5.948

# %%
df15MergedFrom = df.merge(dfHP15, left_on = 'Origin', right_on = 'Country', how ='inner')

# %%
df_groupedOrigin = df15Merged.groupby(['Origin','Year']).agg({'Value':'sum','Happiness Score':'mean','Economy (GDP per Capita)':'mean','Family':'mean','Health (Life Expectancy)':'mean','Freedom':'mean','Trust (Government Corruption)':'mean'})
df_groupedOrigin.sort_values(['Value'],ascending = 0).head(5)
# Out:
#                                              Family   Freedom  \
# Origin                               Year
# Syrian Arab Rep.                     2015  1.198759  0.480885
# Afghanistan                          2015  1.221237  0.495065
# Iraq                                 2015  1.210677  0.482690
# Serbia and Kosovo: S/RES/1244 (1999) 2015  1.251192  0.547767
# Pakistan                             2015  1.215169  0.495514
#
#                                            Happiness Score  \
# Origin                               Year
# Syrian Arab Rep.                     2015         6.311541
# Afghanistan                          2015         6.402107
# Iraq                                 2015         6.328035
# Serbia and Kosovo: S/RES/1244 (1999) 2015         6.729401
# Pakistan                             2015         6.340777
#
#                                            Trust (Government Corruption)  \
# Origin                               Year
# Syrian Arab Rep.                     2015                       0.182278
# Afghanistan                          2015                       0.201458
# Iraq                                 2015                       0.190892
# Serbia and Kosovo: S/RES/1244 (1999) 2015                       0.238246
# Pakistan                             2015                       0.194875
#
#                                            Health (Life Expectancy)   Value  \
# Origin                               Year
# Syrian Arab Rep.                     2015                  0.866746  538297
# Afghanistan                          2015                  0.869286  409089
# Iraq                                 2015                  0.866967  278889
# Serbia and Kosovo: S/RES/1244 (1999) 2015                  0.888366  175314
# Pakistan                             2015                  0.878375   76654
#
#                                            Economy (GDP per Capita)
# Origin                               Year
# Syrian Arab Rep.                     2015                  1.234347
# Afghanistan                          2015                  1.248332
# Iraq                                 2015                  1.243165
# Serbia and Kosovo: S/RES/1244 (1999) 2015                  1.289031
# Pakistan                             2015                  1.245656

# %%
df_groupedOrigin = df_groupedOrigin.reset_index()
df_groupedOrigin = df_groupedOrigin.rename(columns={'Origin': 'Country'})

# %%
del df_groupedOrigin['Value']
del df_groupedOrigin['Year']
del df_groupedOrigin['Happiness Score']
#del df_groupedOrigin['index']
#del df_groupedOrigin['level_0']

# %% [markdown]
# # Top 5 Countries Originated From in 2015

# %%
dfSyrianArabRep = df_groupedOrigin[(df_groupedOrigin['Country']=='Syrian Arab Rep.')]
df_groupedOrigin[(df_groupedOrigin['Country']=='Syrian Arab Rep.')]
ax = dfSyrianArabRep.plot(kind = 'bar',title = "Syrian Arab Rep. Happiness",figsize=(16, 9))
ax.set_xlabel("Happiness Value Type", fontsize=20)
ax.set_ylabel("Rate of Happiness Value", fontsize=20)
ax.set_title("Syrian Arab Rep. Happiness", fontsize=30)
ax.set_ylim([0,1.4])
# Out:
# (0, 1.4)

# %% [markdown]
# ## Happiness Score is 3.006

# %%
dfAfghanisthan = df_groupedOrigin[(df_groupedOrigin['Country']=='Afghanistan')]
df_groupedOrigin[(df_groupedOrigin['Country']=='Afghanistan')]
ax = dfAfghanisthan.plot(kind = 'bar',title = "Afghanistan Happiness",figsize=(16, 9))
ax.set_xlabel("Happiness Value Type", fontsize=20)
ax.set_ylabel("Rate of Happiness Value", fontsize=20)
ax.set_title("Afghanistan Happiness", fontsize=30)
ax.set_ylim([0,1.4])
# Out:
# (0, 1.4)

# %% [markdown]
# ## Happiness Score is 3.575

# %%
dfSyrianArabRep = df_groupedOrigin[(df_groupedOrigin['Country']=='Iraq')]
df_groupedOrigin[(df_groupedOrigin['Country']=='Iraq')]
ax = dfSyrianArabRep.plot(kind = 'bar',title = "Iraq Happiness",figsize=(16, 9))
ax.set_xlabel("Happiness Value Type", fontsize=20)
ax.set_ylabel("Rate of Happiness Value", fontsize=20)
ax.set_title("Iraq Happiness", fontsize=30)
ax.set_ylim([0,1.4])
# Out:
# (0, 1.4)

# %%
dfSerbiaAndKosovo = df_groupedOrigin[(df_groupedOrigin['Country']=='Serbia and Kosovo: S/RES/1244 (1999)')]
df_groupedOrigin[(df_groupedOrigin['Country']=='Serbia and Kosovo: S/RES/1244 (1999)')]
ax = dfSerbiaAndKosovo.plot(kind = 'bar',title = "Serbia and Kosovo Happiness",figsize=(16, 9))
ax.set_xlabel("Happiness Value Type", fontsize=20)
ax.set_ylabel("Rate of Happiness Value", fontsize=20)
ax.set_title("Serbia and Kosovo Happiness", fontsize=30)
ax.set_ylim([0,1.4])
# Out:
# (0, 1.4)

# %% [markdown]
# ## Happiness Score is 5.123

# %%
dfPakistan = df_groupedOrigin[(df_groupedOrigin['Country']=='Pakistan')]
df_groupedOrigin[(df_groupedOrigin['Country']=='Pakistan')]
ax = dfSyrianArabRep.plot(kind = 'bar',title = "Pakistan Happiness",figsize=(16, 9))
ax.set_xlabel("Happiness Value Type", fontsize=20)
ax.set_ylabel("Rate of Happiness Value", fontsize=20)
ax.set_title("Pakistan Happiness", fontsize=30)
ax.set_ylim([0,1.4])
# Out:
# (0, 1.4)

# %% [markdown]
# ## Happiness Score is 5.194

# %%
df_grouped
# Out:
#                    Country   Family  Freedom  Trust (Government Corruption)  \
# 0                  Albania  0.80434  0.35733                        0.06413
# 1                Australia  1.30923  0.65124                        0.35637
# 2                  Austria  1.29704  0.62433                        0.18676
# 3                  Belgium  1.28566  0.58450                        0.22540
# 4   Bosnia and Herzegovina  0.91916  0.09245                        0.00227
# 5                 Bulgaria  1.10614  0.30587                        0.00872
# 6                   Canada  1.32261  0.63297                        0.32957
# 7                  Croatia  0.79624  0.25883                        0.02430
# 8                   Cyprus  0.89318  0.40672                        0.06146
# 9                  Denmark  1.36058  0.64938                        0.48357
# 10                 Estonia  1.22791  0.44888                        0.15184
# 11                 Finland  1.31826  0.64169                        0.41372
# 12                  France  1.26038  0.55011                        0.20646
# 13                 Germany  1.29937  0.61477                        0.21843
# 14                  Greece  0.92933  0.07699                        0.01397
# 15                 Hungary  1.20215  0.32112                        0.02758
# 16                 Iceland  1.40223  0.62877                        0.14145
# 17                 Ireland  1.36948  0.61777                        0.28703
# 18                   Italy  1.19777  0.26236                        0.02901
# 19                   Japan  1.25712  0.49615                        0.18060
# 20                  Latvia  1.09562  0.29671                        0.06332
# 21               Lithuania  1.25745  0.21342                        0.01031
# 22              Luxembourg  1.21963  0.61583                        0.37798
# 23                   Malta  1.30203  0.60365                        0.13586
# 24              Montenegro  0.90557  0.18260                        0.14296
# 25             Netherlands  1.28017  0.61576                        0.31814
# 26             New Zealand  1.31967  0.63938                        0.42922
# 27                  Norway  1.33095  0.66973                        0.36503
# 28                  Poland  1.27948  0.53122                        0.04212
# 29                Portugal  1.13935  0.51469                        0.01078
# 30                 Romania  0.88588  0.35068                        0.00649
# 31                Slovakia  1.26999  0.31751                        0.03431
# 32                Slovenia  1.27385  0.60855                        0.03787
# 33                   Spain  1.31379  0.45951                        0.06398
# 34                  Sweden  1.28907  0.65980                        0.43844
# 35             Switzerland  1.34951  0.66557                        0.41978
# 36                  Turkey  0.94632  0.22815                        0.15746
#
#     Health (Life Expectancy)  Economy (GDP per Capita)
# 0                    0.81325                   0.87867
# 1                    0.93156                   1.33358
# 2                    0.89042                   1.33723
# 3                    0.89667                   1.30782
# 4                    0.79081                   0.83223
# 5                    0.76649                   1.01216
# 6                    0.90563                   1.32629
# 7                    0.78805                   1.08254
# 8                    0.92356                   1.20813
# 9                    0.87464                   1.32548
# 10                   0.77361                   1.15174
# 11                   0.88911                   1.29025
# 12                   0.94579                   1.27778
# 13                   0.89186                   1.32792
# 14                   0.88213                   1.15406
# 15                   0.75905                   1.12094
# 16                   0.94784                   1.30232
# 17                   0.89533                   1.33596
# 18                   0.95446                   1.25114
# 19                   0.99111                   1.27074
# 20                   0.72437                   1.11312
# 21                   0.73128                   1.14723
# 22                   0.91894                   1.56391
# 23                   0.88721                   1.20740
# 24                   0.72521                   0.97438
# 25                   0.89284                   1.32944
# 26                   0.90837                   1.25018
# 27                   0.88521                   1.45900
# 28                   0.77903                   1.12555
# 29                   0.87519                   1.15991
# 30                   0.76890                   1.04345
# 31                   0.78902                   1.16891
# 32                   0.87337                   1.18498
# 33                   0.95562                   1.23011
# 34                   0.91087                   1.33171
# 35                   0.94143                   1.39651
# 36                   0.73172                   1.06098

# %%
df_groupedNew = df15Merged.groupby(['Country / territory of asylum/residence','Year']).agg({'Value':'sum','Happiness Score':'mean','Economy (GDP per Capita)':'mean','Family':'mean','Health (Life Expectancy)':'mean','Freedom':'mean','Trust (Government Corruption)':'mean'})
df_groupedNew.sort_values(['Value'],ascending = 0).head(5)

# %%
df_ChartsNStuff = df_groupedNew
df_ChartsNStuff = df_ChartsNStuff.reset_index()
dfFamily = df_ChartsNStuff.copy()
df_ChartsNStuff
# Out:
#    Country / territory of asylum/residence  Year   Family  Freedom  \
# 0                                  Albania  2015  0.80434  0.35733
# 1                                Australia  2015  1.30923  0.65124
# 2                                  Austria  2015  1.29704  0.62433
# 3                                  Belgium  2015  1.28566  0.58450
# 4                   Bosnia and Herzegovina  2015  0.91916  0.09245
# 5                                 Bulgaria  2015  1.10614  0.30587
# 6                                   Canada  2015  1.32261  0.63297
# 7                                  Croatia  2015  0.79624  0.25883
# 8                                   Cyprus  2015  0.89318  0.40672
# 9                                  Denmark  2015  1.36058  0.64938
# 10                                 Estonia  2015  1.22791  0.44888
# 11                                 Finland  2015  1.31826  0.64169
# ..                                     ...   ...      ...      ...
# 25                             Netherlands  2015  1.28017  0.61576
# 26                             New Zealand  2015  1.31967  0.63938
# 27                                  Norway  2015  1.33095  0.66973
# 28                                  Poland  2015  1.27948  0.53122
# 29                                Portugal  2015  1.13935  0.51469
# 30                                 Romania  2015  0.88588  0.35068
# 31                                Slovakia  2015  1.26999  0.31751
# 32                                Slovenia  2015  1.27385  0.60855
# 33                                   Spain  2015  1.31379  0.45951
# 34                                  Sweden  2015  1.28907  0.65980
# 35                             Switzerland  2015  1.34951  0.66557
# 36                                  Turkey  2015  0.94632  0.22815
#
#     Happiness Score  Trust (Government Corruption)  Health (Life Expectancy)  \
# 0             4.959                        0.06413                   0.81325
#
#     Happiness Score  Trust (Government Corruption)  Health (Life Expectancy)  \
# 0             4.959                        0.06413                   0.81325
# 1             7.284                        0.35637                   0.93156
# 2             7.200                        0.18676                   0.89042
# 3             6.937                        0.22540                   0.89667
# 4             4.949                        0.00227                   0.79081
# 5             4.218                        0.00872                   0.76649
# 6             7.427                        0.32957                   0.90563
# 7             5.759                        0.02430                   0.78805
# 8             5.689                        0.06146                   0.92356
# 9             7.527                        0.48357                   0.87464
# 10            5.429                        0.15184                   0.77361
# 11            7.406                        0.41372                   0.88911
# ..              ...                            ...                       ...
# 25            7.378                        0.31814                   0.89284
# 26            7.286                        0.42922                   0.90837
# 27            7.522                        0.36503                   0.88521
# 28            5.791                        0.04212                   0.77903
# 29            5.102                        0.01078                   0.87519
# 30            5.124                        0.00649                   0.76890
# 31            5.995                        0.03431                   0.78902
# 32            5.848                        0.03787                   0.87337
# 33            6.329                        0.06398                   0.95562
# 34            7.364                        0.43844                   0.91087
# 35            7.587                        0.41978                   0.94143
# 36            5.332                        0.15746                   0.73172
#
#      Value  Economy (GDP per Capita)
# 0      586                   0.87867
# 1    12397                   1.33358
# 2    92375                   1.33723
# 3    40325                   1.30782
# 4       49                   0.83223
# 5    20163                   1.01216
# 6    16131                   1.32629
# 7      422                   1.08254
# 8     2112                   1.20813
# 9    21427                   1.32548
# 10     232                   1.15174
# 11   32769                   1.29025
# ..     ...                       ...
# 25   86198                   1.32944
# 26     704                   1.25018
# 27   61046                   1.45900
# 28   20508                   1.12555
# 29    1792                   1.15991
# 30    2534                   1.04345
# 31     538                   1.16891
# 32     524                   1.18498
# 33   26732                   1.23011
# 34  312918                   1.33171
# 35   76246                   1.39651
# 36  267170                   1.06098
#
# [37 rows x 9 columns]

# %%
dfFamily = dfFamily[dfFamily['Country / territory of asylum/residence'].isin(['Germany','Hungary','Sweden','Turkey','Italy'])]
dfFamily = dfFamily.set_index('Country / territory of asylum/residence')

# %%
#df_Family.loc[(df_Family['Country / territory of asylum/residence'] == "Pakistan") & df_Family['Country / territory of asylum/residence'] == "Italy)]

#df_Family.loc[(df_Family['Country / territory of asylum/residence'] == "Pakistan") & (df_Family['Country / territory of asylum/residence'] == "Italy")]

#pakistananditaly = df_Family.loc[(df_Family['Country / territory of asylum/residence'] == "Pakistan") & (df_Family['Country / territory of asylum/residence'] == "Italy")]
#pakistananditaly

ax = dfFamily.plot(kind = 'bar',figsize=(16, 9))
ax.set_xlabel("Country", fontsize=20)
ax.set_ylabel("Family", fontsize=20)
ax.set_title("Family Rating Top 5 Countries Seeking Asylum To (2015)", fontsize=30)
ax.set_ylim([0,1.4])
# Out:
# (0, 1.4)

# %%
dfFreedom = df_ChartsNStuff.copy()

# %%
del dfFreedom['Year']
del dfFreedom['Family']
del dfFreedom['Happiness Score']
del dfFreedom['Trust (Government Corruption)']
del dfFreedom['Health (Life Expectancy)']
del dfFreedom['Value']
del dfFreedom['Economy (GDP per Capita)']
dfFreedom = dfFreedom[dfFreedom['Country / territory of asylum/residence'].isin(['Germany','Hungary','Sweden','Turkey','Italy'])]
dfFreedom = dfFreedom.set_index('Country / territory of asylum/residence')

# %%
ax = dfFreedom.plot(kind = 'bar',figsize=(16, 9))
ax.set_xlabel("Country", fontsize=20)
ax.set_ylabel("Freedom", fontsize=20)
ax.set_title("Freedom Rating Top 5 Countries Seeking Asylum To (2015)", fontsize=30)

# %%
dfHappiness = df_ChartsNStuff.copy()

# %%
del dfHappiness['Year']
del dfHappiness['Family']
del dfHappiness['Freedom']
del dfHappiness['Trust (Government Corruption)']
del dfHappiness['Health (Life Expectancy)']
del dfHappiness['Value']
del dfHappiness['Economy (GDP per Capita)']
dfHappiness = dfHappiness[dfHappiness['Country / territory of asylum/residence'].isin(['Germany','Hungary','Sweden','Turkey','Italy'])]
dfHappiness = dfHappiness.set_index('Country / territory of asylum/residence')

# %%
ax = dfHappiness.plot(kind = 'bar',figsize=(16, 9))
ax.set_xlabel("Country", fontsize=20)
ax.set_ylabel("Happiness", fontsize=20)
ax.set_title("Happiness Rating Top 5 Countries Seeking Asylum To (2015)", fontsize=30)

# %%
dfTrust = df_ChartsNStuff.copy()

# %%
del dfTrust['Year']
del dfTrust['Family']
del dfTrust['Freedom']
del dfTrust['Happiness Score']
del dfTrust['Health (Life Expectancy)']
del dfTrust['Value']
del dfTrust['Economy (GDP per Capita)']
dfTrust = dfTrust[dfTrust['Country / territory of asylum/residence'].isin(['Germany','Hungary','Sweden','Turkey','Italy'])]
dfTrust = dfTrust.set_index('Country / territory of asylum/residence')

# %%
ax = dfTrust.plot(kind = 'bar',figsize=(16, 9))
ax.set_xlabel("Country", fontsize=20)
ax.set_ylabel("Trust/Government Corruption", fontsize=20)
ax.set_title("Trust/Government Corruption Rating Top 5 Countries Seeking Asylum To (2015)", fontsize=30)

# %%
dfHealth = df_ChartsNStuff.copy()

# %%
del dfHealth['Year']
del dfHealth['Family']
del dfHealth['Freedom']
del dfHealth['Happiness Score']
del dfHealth['Trust (Government Corruption)']
del dfHealth['Value']
del dfHealth['Economy (GDP per Capita)']
dfHealth = dfHealth[dfHealth['Country / territory of asylum/residence'].isin(['Germany','Hungary','Sweden','Turkey','Italy'])]
dfHealth = dfHealth.set_index('Country / territory of asylum/residence')

# %%
ax = dfHealth.plot(kind = 'bar',figsize=(16, 9))
ax.set_xlabel("Country", fontsize=20)
ax.set_ylabel("Health", fontsize=20)
ax.set_title("Health Rating Top 5 Countries Seeking Asylum To (2015)", fontsize=30)

# %%
dfEconomy = df_ChartsNStuff.copy()

# %%
del dfEconomy['Year']
del dfEconomy['Family']
del dfEconomy['Freedom']
del dfEconomy['Happiness Score']
del dfEconomy['Trust (Government Corruption)']
del dfEconomy['Value']
del dfEconomy['Health (Life Expectancy)']
dfEconomy = dfEconomy[dfEconomy['Country / territory of asylum/residence'].isin(['Germany','Hungary','Sweden','Turkey','Italy'])]
dfEconomy = dfEconomy.set_index('Country / territory of asylum/residence')

# %%
ax = dfEconomy.plot(kind = 'bar',figsize=(16, 9))
ax.set_xlabel("Country", fontsize=20)
ax.set_ylabel("Economy", fontsize=20)
ax.set_title("Economy Rating Top 5 Countries Seeking Asylum To (2015)", fontsize=30)
