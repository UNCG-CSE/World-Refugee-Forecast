# %%
import pandas as pd
import numpy as np
pd.set_option('html', True)
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 25)

# %%
df = pd.read_csv("../data/asylum_seekers.csv")

# %%
df_filtered15 = df[(df.Year == 2015)]
df_filtered16 = df[(df.Year == 2016)]
df_filtered15
# Out:
#         Year Country / territory of asylum/residence       Origin  \
# 108034  2015                United States of America  Afghanistan
# 108035  2015                United States of America  Afghanistan
# 108036  2015                            South Africa  Afghanistan
# 108037  2015                            South Africa  Afghanistan
# 108038  2015                                Pakistan  Afghanistan
# 108039  2015                                Pakistan  Afghanistan
# 108040  2015                                  Panama  Afghanistan
# 108041  2015                             Philippines  Afghanistan
# 108042  2015                        Papua New Guinea  Afghanistan
# 108043  2015                                  Poland  Afghanistan
# 108044  2015                                  Poland  Afghanistan
# 108045  2015                                Portugal  Afghanistan
# ...      ...                                     ...          ...
# ...

# %%
dfHP15 = pd.read_csv("../data/Happiness Index/2015.csv")

# %%
dfHP16 = pd.read_csv("../data/Happiness Index/2016.csv")

# %%
df15Merged = df_filtered15.merge(dfHP15, left_on = 'Country / territory of asylum/residence', right_on = 'Country', how ='inner')

# %%
df16Merged = df_filtered16.merge(dfHP16, left_on = 'Country / territory of asylum/residence', right_on = 'Country', how ='inner')

# %%
df15Grouped = df15Merged.groupby(['Country / territory of asylum/residence'])[["Tota pending start-year"]].sum()

# %%
df15Grouped.sort(['Tota pending start-year'], ascending = 1)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   """Entry point for launching an IPython kernel.
#                                                              Tota pending start-year
# Country / territory of asylum/residence
# Montenegro                               0000030000190000020130000030000000036000020
# Sierra Leone                                                                11104170
# Ecuador                                                                        11583
# Bahrain                                                                      3390000
# Afghanistan                                                                      NaN
# Albania                                                                          NaN
# Algeria                                                                          NaN
# ...
