# %%
import pandas as pd
import numpy as np
pd.set_option('html', True)
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 25)

# %%
dfPassport = pd.read_csv("../data/passport-index.csv")
dfPassport
# Out:
#                       Country  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 0                 Afghanistan            1        0        0        0       0
# 1                     Albania            0        1        0        1       0
# 2                     Algeria            0        0        1        0       0
# 3                     Andorra            0        1        0        1       0
# 4                      Angola            0        0        0        0       1
# 5         Antigua and Barbuda            0        1        0        1       0
# 6                   Argentina            0        1        0        1       0
# 7                     Armenia            0        1        0        0       0
# 8                   Australia            0        1        0        1       0
# 9                     Austria            0        1        0        1       0
# 10                 Azerbaijan            0        1        0        0       0
# ...

# %%
dfAsylumSeekers = pd.read_csv("../data/ref_by_c_asylum/ref_by_c_asylum.csv")
dfAsylumSeekers
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-11-4a7aaa8ef2fd> in <module>()
# ----> 1 dfAsylumSeekers = pd.read_csv("../data/ref_by_c_asylum/ref_by_c_asylum.csv")
#       2 dfAsylumSeekers
#
# ...
